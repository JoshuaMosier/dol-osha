# %%
# imports
import pandas as pd

# %%
file_path = 'data/injury data/ITA Data CY 2023.csv'
data = pd.read_csv(file_path)
# Out:
# C:\Users\joshr\AppData\Local\Temp\ipykernel_22488\1426374055.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)

# %%
# Get a summary of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374662 entries, 0 to 374661
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id                            374662 non-null  int64
#  1   establishment_name            374662 non-null  object
#  2   establishment_id              374662 non-null  int64
#  3   ein                           335124 non-null  object
#  4   company_name                  356027 non-null  object
#  5   street_address                374658 non-null  object
#  6   city                          374661 non-null  object
#  7   state                         374662 non-null  object
#  8   zip_code                      374662 non-null  float64
#  9   naics_code                    374662 non-null  int64
#  10  naics_year                    372385 non-null  float64
#  11  industry_description          350341 non-null  object
# ...

# %%
# Summary statistics for numeric columns
data.describe()
# Out:
#                  id  establishment_id      zip_code     naics_code  \
# count  3.746620e+05      3.746620e+05  3.746620e+05  374662.000000
# mean   2.289988e+06      8.781320e+05  1.958278e+07  467416.333856
# std    1.088017e+05      3.393767e+05  1.127422e+08  163235.577626
# min    2.101836e+06      4.193000e+04  0.000000e+00  101660.000000
# 25%    2.195708e+06      6.665952e+05  3.003800e+04  332994.000000
# 50%    2.289788e+06      1.005094e+06  5.305100e+04  452112.000000
# 75%    2.384087e+06      1.140904e+06  8.012400e+04  561910.000000
# max    2.478451e+06      1.238225e+06  9.980000e+08  999999.000000
#
#           naics_year  establishment_type           size  \
# count  372385.000000       373972.000000  374662.000000
# mean     2021.423473            1.096071      11.866696
# std         2.030706            0.375116       9.757425
# min      2012.000000            0.000000       1.000000
# 25%      2022.000000            1.000000       2.000000
# ...
